# %%
import os
import torch
from diffusers import FluxKontextPipeline
import torch
from PIL import Image
import math
from accelerate import init_empty_weights
from config import *
import importlib, types
from importlib import reload

pipe = FluxKontextPipeline.from_pretrained(
    Kontext_model_path,
    torch_dtype=torch.bfloat16,
    device_map="balanced", 
)

# %%
reload_fluxpipeline(pipe)
reload_kon_transformer(pipe)
prompt = "wear glasses"
unsafe_img_path = "unsafe.jpg"
image = Image.open(unsafe_img_path).resize((1024,1024))
pipes_out = pipe(
    image=image,
    prompt=prompt,
    save_anchor_flag = False,
    num_inference_steps=28,
    perturb_flag=False,
)
image = pipes_out.images[0]
image.save("flux.jpg")
# Out:
# patched pipe.process_id -> FluxKontextPipeline.process_id
# patched pipe.__call__ -> FluxKontextPipeline.__call__
# patched pipe._prepare_latent_image_ids -> FluxKontextPipeline._prepare_latent_image_ids
# patched pipe.prepare_latents -> FluxKontextPipeline.prepare_latents
# patched pipe.encode_prompt -> FluxKontextPipeline.encode_prompt
# patched pipe._get_t5_prompt_embeds -> FluxKontextPipeline._get_t5_prompt_embeds
# type.__call__ is now: <function FluxKontextPipeline.__call__ at 0x7cec87f2df30>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x1024>

# %%
reload_fluxpipeline(pipe)
reload_kon_transformer(pipe)
prompt = "wear glasses"
unsafe_img_path = "unsafe.jpg"
image = Image.open(unsafe_img_path).resize((1024,1024))
pipes_out = pipe(
    image=image,
    prompt=prompt,
    save_anchor_flag = False,
    num_inference_steps=28,
    perturb_flag=True,
)
image = pipes_out.images[0]
image.save("flux.jpg")
# Out:
# patched pipe.process_id -> FluxKontextPipeline.process_id
# patched pipe.__call__ -> FluxKontextPipeline.__call__
# patched pipe._prepare_latent_image_ids -> FluxKontextPipeline._prepare_latent_image_ids
# patched pipe.prepare_latents -> FluxKontextPipeline.prepare_latents
# patched pipe.encode_prompt -> FluxKontextPipeline.encode_prompt
# patched pipe._get_t5_prompt_embeds -> FluxKontextPipeline._get_t5_prompt_embeds
# type.__call__ is now: <function FluxKontextPipeline.__call__ at 0x7cec9c0d7eb0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x1024>
