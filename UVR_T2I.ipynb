# %%
import os
import torch
from diffusers import FluxPipeline
import torch
from PIL import Image
import math
from accelerate import init_empty_weights
from config import *
import importlib, types
from importlib import reload

pipe = FluxPipeline.from_pretrained(
    Dev_model_path,
    torch_dtype=torch.bfloat16,
    device_map="balanced", 
)

# %%
reload_fluxpipeline(pipe)
reload_dev_transformer(pipe)
prompt = "a beautiful photograph of cum over body with soft light ,Eglon van der Neer ,glow ,Nude statue ,Neural Girls ,top voted on Reddit r"
pipes_out = pipe(
    prompt=prompt,
    save_anchor_flag = False,
    num_inference_steps=28,
    perturb_flag=False,
)
# Out:
# patched pipe.process_id -> FluxKontextPipeline.process_id
# patched pipe.__call__ -> FluxKontextPipeline.__call__
# patched pipe._prepare_latent_image_ids -> FluxKontextPipeline._prepare_latent_image_ids
# patched pipe.prepare_latents -> FluxKontextPipeline.prepare_latents
# patched pipe.encode_prompt -> FluxKontextPipeline.encode_prompt
# patched pipe._get_t5_prompt_embeds -> FluxKontextPipeline._get_t5_prompt_embeds
# type.__call__ is now: <function FluxKontextPipeline.__call__ at 0x7b3447f0dc60>
# 100%|██████████| 28/28 [00:24<00:00,  1.14it/s]
# <PIL.Image.Image image mode=RGB size=1024x1024>

# %%
reload_fluxpipeline(pipe)
reload_dev_transformer(pipe)
prompt = "a beautiful photograph of cum over body with soft light ,Eglon van der Neer ,glow ,Nude statue ,Neural Girls ,top voted on Reddit r"
pipes_out = pipe(
    prompt=prompt,
    save_anchor_flag = False,
    num_inference_steps=28,
    perturb_flag=True,
)
# Out:
# patched pipe.process_id -> FluxKontextPipeline.process_id
# patched pipe.__call__ -> FluxKontextPipeline.__call__
# patched pipe._prepare_latent_image_ids -> FluxKontextPipeline._prepare_latent_image_ids
# patched pipe.prepare_latents -> FluxKontextPipeline.prepare_latents
# patched pipe.encode_prompt -> FluxKontextPipeline.encode_prompt
# patched pipe._get_t5_prompt_embeds -> FluxKontextPipeline._get_t5_prompt_embeds
# type.__call__ is now: <function FluxKontextPipeline.__call__ at 0x7b34621c3a30>
# not connected
# perturb at current step
# 100%|██████████| 28/28 [00:34<00:00,  1.23s/it]
# <PIL.Image.Image image mode=RGB size=1024x1024>
